# %% [markdown]
# # Table of contents
# - [Setup](#setup)
#     - [Target issues](#targetissues)
#     - [Libraries](#libraries)
#     - [Setup](#setup)
# - [Elsevier API](#elsevierAPI)
#     - [NeuroImage 2022 articles](#NeuroImage2022articles)
#         - [Articles overview](#articlesoverview)
#         - [Metadata-database](#metadataDatabase)
#     - [Fetch PDFs](#fetchPDFs)
# - [References](#references)

# %% [markdown]
# <a name='setup'></a>
# # 0. Setup
#
# In this file, I download all papers published in NeuroImage in 2022.
# <br>
# <br>
#
# <a name='targetissues'></a>
# ## 0.1. Target issues
#
# NeuroImage 2022: https://www.sciencedirect.com/journal/neuroimage/issues, issues 246-264.
# <br>
# <br>
#
# <a name='libraries'></a>
# ## 0.2. Libraries

# %%
import pandas as pd
import numpy as np
import requests 
import json 
import os 
import re
import time
from urllib.parse import quote  # Import the quote function for URL encoding

# %% [markdown]
# <a name='setup'></a>
# ## 0.3. Setup
# The *config.json* file contains the API Key and Institution Token; both of which are necessary to use Elsevier's API.
#
# Everyone can freely create an API key on https://dev.elsevier.com/. The institution token, however, is private and unique to each institution. To comply with the rules, this token cannot appear in any browser code or in the address bar and must be kept secure. As such, it will not appear in my code. This also means that if someone where to run this notebook, they would not be able to get the papers themselves.

# %%
## Load configuration 
con_file = open("config.json")
config = json.load(con_file)
con_file.close()

## Initialize client 
api_key = config['apikey'] 
inst_token = config['insttoken']

# %% [markdown]
# <a name = 'elsevierAPI'></a>
# # 1. Elsevier API
#
# I use Elsevier's API to download the PDFs published in NeuroImage.
# Elsevier has a Python SDK called **elsapy**. In this github repository, there are multiple files with code snippets, that I read as inspiration to understand how to use their API.
#
# References:
# - Elsapy. (2023). [Python]. Elsevier Developers. https://github.com/ElsevierDev/elsapy (Original work published 2016)

# %% [markdown]
# <a name='NeuroImage2022articles'></a>
# ## 1.1. NeuroImage 2022 articles
#
# Steps:
# * Formulate the correct search to get the 834 articles (815 if I exclude the 'Editorial board' articles from each volume)
# * Extract the metadata about each journal
#
# <br>
# <br>
#
# <a name='articlesoverview'></a>
# ### 1.1.1. Articles overview
# The function **get_articles_info** uses Elsevier's ScienceDirect API to search ScienceDirect for the available information on the articles specified in my request.
#
# References:
# - Elsevier B.V. (2023d). ScienceDirect Search API Migration. Elsevier Developer Portal. https://dev.elsevier.com/tecdoc_sdsearch_migration.html

# %%
def get_articles_info(api_key, inst_token, search_query, publication_date, volume_range, show_per_request, page):
    """Fetches scientific articles' information from ScienceDirect based on 
    specified search criteria.
    
    Parameters: 
    :param api_key (str): Elsevier API key for authentication.
    :param inst_token (str): Elsevier institution token for access.
    :param search_query (str): The search query for articles.
    :param publication_date (str): The publication date or year for filtering articles.
    :param volume_range (str): The range of publication volumes for filtering articles.
    :param show_per_request (int): The number of articles to retrieve per request.
    :param page (int): The current page number for pagination.
    
    Returns: 
    :return: pandas.DataFrame object containing information about the fetched articles.
    """
    # Base URL for the PUT request
    base_url = 'https://api.elsevier.com/content/search/sciencedirect'
    
    # Header for the request 
    headers_param = {
        'Accept': 'application/json',
        'X-ELS-APIKey': api_key,
        'X-ELS-Insttoken': inst_token
    }
    
    # Empty list to store all the articles 
    all_articles = []
    
    while True: 
        # Increment the page number for pagiation 
        page += 1
    
        # The PUT request in JSON format 
        put_body = {
            'qs': search_query,
            'date': publication_date,  
            'pub': search_query,  
            'volume': volume_range, 
            'view': 'COMPLETE',
            'filters': {
                'openAccess': 'true',
            },
            'display': {
                'offset': (page-1) * show_per_request, 
                'show': show_per_request, 
                'sortBy': 'date'
            }
        }

        # Convert the PUT body to JSON format
        put_body_json = json.dumps(put_body)

        # Send the PUT request
        response = requests.put(base_url, data=put_body_json, headers=headers_param)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            data = response.json()
            articles_on_page = data.get("results", [])
            
            if not articles_on_page:
                break # No more articles to fetch 
            
            all_articles.extend(articles_on_page)
            
            # Rate limiting to avoid hitting an API rate limit 
            time.sleep(1) # sleep for one second between requests 
        
        else:
            # Handle error cases
            print(f"Request failed with status code: {response.status_code}")
            break
        
    # Create a dataframe from all the articles 
    df = pd.DataFrame(all_articles)
    return df

# %%
search_query = 'NeuroImage'
publication_date = '2022'
volume_range = '246-264'
show_per_request = 50 
page = 0

articles_df = get_articles_info(api_key, inst_token, search_query, publication_date, volume_range, show_per_request, page)

# %%
print(f"Total articles fetched: {len(articles_df)}")
# Out:
# Total articles fetched: 834

# %%
articles_df
# Out:
#                                   doi                  loadDate  openAccess  \
# 0       10.1016/S1053-8119(22)00918-1  2022-12-09T00:00:00.000Z        True
# 1    10.1016/j.neuroimage.2022.119763  2022-11-24T00:00:00.000Z        True
# 2    10.1016/j.neuroimage.2022.119764  2022-11-24T00:00:00.000Z        True
# 3    10.1016/j.neuroimage.2022.119768  2022-11-24T00:00:00.000Z        True
# 4    10.1016/j.neuroimage.2022.119769  2022-11-24T00:00:00.000Z        True
# ..                                ...                       ...         ...
# 829  10.1016/j.neuroimage.2021.118745  2021-11-19T00:00:00.000Z        True
# 830  10.1016/j.neuroimage.2021.118714  2021-11-18T00:00:00.000Z        True
# 831  10.1016/j.neuroimage.2021.118738  2021-11-17T00:00:00.000Z        True
# 832  10.1016/j.neuroimage.2021.118698  2021-11-16T00:00:00.000Z        True
# 833  10.1016/j.neuroimage.2021.118718  2021-11-10T00:00:00.000Z        True
#
#                    pages                pii publicationDate sourceTitle  \
# 0    {'first': '119797'}  S1053811922009181      2022-12-01  NeuroImage
# 1    {'first': '119763'}  S1053811922008849      2022-12-01  NeuroImage
# 2    {'first': '119764'}  S1053811922008850      2022-12-01  NeuroImage
# 3    {'first': '119768'}  S1053811922008898      2022-12-01  NeuroImage
# 4    {'first': '119769'}  S1053811922008904      2022-12-01  NeuroImage
# ..                   ...                ...             ...         ...
# 829  {'first': '118745'}  S105381192101017X      2022-02-01  NeuroImage
# 830  {'first': '118714'}  S1053811921009861      2022-02-01  NeuroImage
# 831  {'first': '118738'}  S1053811921010107      2022-02-01  NeuroImage
# 832  {'first': '118698'}  S105381192100971X      2022-02-15  NeuroImage
# 833  {'first': '118718'}  S1053811921009903      2022-03-31  NeuroImage
#
#                                                  title  \
# 0                                      Editorial Board
# 1    An optimized reference tissue method for quant...
# 2    Shared and distinct neural activity during ant...
# 3    Sample size requirement for achieving multisit...
# 4    Dissociation and hierarchy of human visual pat...
# ..                                                 ...
# 829  Mapping cortico-subcortical sensitivity to 4 H...
# 830  An MRI method for parcellating the human stria...
# 831  Advances in spiral fMRI: A high-resolution stu...
# 832  Delta- and theta-band cortical tracking and ph...
# 833  Does powder averaging remove dispersion bias i...
#
#                                                    uri volumeIssue  \
# 0    https://www.sciencedirect.com/science/article/...  Volume 264
# 1    https://www.sciencedirect.com/science/article/...  Volume 264
# 2    https://www.sciencedirect.com/science/article/...  Volume 264
# 3    https://www.sciencedirect.com/science/article/...  Volume 264
# 4    https://www.sciencedirect.com/science/article/...  Volume 264
# ..                                                 ...         ...
# 829  https://www.sciencedirect.com/science/article/...  Volume 246
# 830  https://www.sciencedirect.com/science/article/...  Volume 246
# 831  https://www.sciencedirect.com/science/article/...  Volume 246
# 832  https://www.sciencedirect.com/science/article/...  Volume 247
# 833  https://www.sciencedirect.com/science/article/...  Volume 248
#
#                                                authors
# 0                                                  NaN
# 1    [{'order': 1, 'name': 'Kenji Tagai'}, {'order'...
# 2    [{'order': 1, 'name': 'Yu Chen'}, {'order': 2,...
# 3    [{'order': 1, 'name': 'Pravesh Parekh'}, {'ord...
# 4    [{'order': 1, 'name': 'Xuetong Ding'}, {'order...
# ..                                                 ...
# 829  [{'order': 1, 'name': 'Søren A. Fuglsang'}, {'...
# 830  [{'order': 1, 'name': 'JL Waugh'}, {'order': 2...
# 831  [{'order': 1, 'name': 'Lars Kasper'}, {'order'...
# 832  [{'order': 1, 'name': 'Adam Attaheri'}, {'orde...
# 833  [{'order': 1, 'name': 'Mariam Andersson'}, {'o...
#
# [834 rows x 11 columns]

# %% [markdown]
# <a name='metadataDatabase'></a>
# ### 1.1.2. Metadata-database
# As I was unsure if there were any additional metadata pertaining to each article that would be relevant, I defined a function to get and save this information. To get the metadata for all the articles, I use Elsevier's **Article Metadata API**.
#
# Steps:
# - For each doi in article_df['doi']
#     - use https://api.elsevier.com/content/metadata/article with
#         - header_params as normal
#         - the query_params should probably just be 'query' with the doi
#         - the 'get' method
#
# References:
# * Elsevier B.V. (2023b). Article Metadata API. Elsevier Developer Portal. https://dev.elsevier.com/documentation/ArticleMetadataAPI.wadl
# * Elsevier B.V. (2023c). ScienceDirect Article Metadata Guide. Elsevier Developer Portal. https://dev.elsevier.com/sd_article_meta_tips.html

# %%
def get_metadata_for_dois(api_key, inst_token, df):
    """Fetches metadata for a list of DOIs from ScienceDirect.

    Parameters: 
    :param api_key (str): Elsevier API key for authentication.
    :param inst_token (str): Elsevier institution token for access.
    :param df (pandas.DataFrame): A pandas.DataFrame object containing a 'doi' column with DOIs to fetch metadata for.
    
    Returns:
    :return: pandas.DataFrame object containing the fetched metadata for each DOI.
    """
    # Dase URL for the article metadata endpoint
    metadata_base_url = 'https://api.elsevier.com/content/metadata/article'

    # Header for the request
    headers_param = {
        'Accept': 'application/json',
        'X-ELS-APIKey': api_key,
        'X-ELS-Insttoken': inst_token
    }
    
    # Query parameters for the request
    query_params = {
        'view': 'COMPLETE', 
        'count': '1'  # Set count to 1 to fetch only one result for each DOI
    }
    
    # Empty list to store the metadata for each article
    metadata_list = []
    count = 0

    for doi in df['doi']:
        # Encode the DOI and add it to the query parameters
        doi_encoded = quote(doi)
        query_params['query'] = f'doi({doi_encoded})'

        # GET request to fetch metadata for the article
        response = requests.get(metadata_base_url, headers=headers_param, params=query_params)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            metadata = response.json()
            metadata_list.append(metadata)
            count += 1
            # print("Fetched", count, "articles")
        else:
            # Handle error cases
            print(f"Failed to fetch metadata for DOI: {doi}. Status code: {response.status_code}")

    # Create a DataFrame from the list of metadata
    metadata_df = pd.DataFrame(metadata_list)

    return metadata_df

# %%
metadata_df = get_metadata_for_dois(api_key, inst_token, articles_df)

# %%
metadata_df['search-results'].loc[1]

# %% [markdown]
# <a name='fetchPDFs'></a>
# ## 1.2. Fetch PDF's
#
# To get the PDFs, I have to define a couple of functions, some of which ensure that if they are called multiple times, the same PDFs won't get downloaded multiple times. To get the PDFs, I use Elsevier's Article (Full Text) Retrieval API.
#
# References:
# - Elsevier B.V. (2023a). Article (Full Text) Retrieval API. Elsevier Developer Portal. https://dev.elsevier.com/documentation/ArticleRetrievalAPI.wadl#d1e52

# %%
def load_downloaded_info():
    """This function loads information about downloaded articles from a JSON file 
    or initializes empty sets if the file doesn't exist.
    """
    global downloaded_dois, downloaded_article_names
    info_file_path = 'downloadedPDFs_info.json'  # File path
    if os.path.exists(info_file_path):
        with open(info_file_path, 'r') as file:
            data = json.load(file)
            downloaded_dois = set(data.get('DOIs', []))
            downloaded_article_names = set(data.get('article_names', []))
    else:
        # Create the file if it doesn't exist
        downloaded_dois = set()
        downloaded_article_names = set()

def save_downloaded_info():
    """This function saves information about downloaded articles (DOIs and article names) 
    to a JSON file.
    """
    data = {
        'DOIs': list(downloaded_dois),
        'article_names': list(downloaded_article_names)
    }
    info_file_path = 'downloadedPDFs_info.json'  # File path
    with open(info_file_path, 'w') as file:
        json.dump(data, file, indent=4)  # Indent for readability     

def download_pdf(api_key, inst_token, df, doi_column='doi', title_column='title'):
    """This function downloads PDF articles based on their DOI and saves them in 
    specific directories. It checks if an article with the same DOI has been 
    downloaded before and avoids duplicate downloads.
    
    Parameters:
    :param api_key (str): Elsevier API key for authentication. 
    :param inst_token (str): Elsevier institution token for API access.
    :param df (pandas.DataFrame): The pandas.DataFrame object containing article information.
    :param doi_column (str, optional): The name of the DOI column in the DataFrame. Defaults to 'doi'.
    :param title_column (str, optional): The name of the article title column in the DataFrame. Defaults to 'title'.

    Note: This function creates directories to organize saved PDFs based on the article title. 
    PDFs with the title 'Editorial board' are saved in the 'fulltext_editorialboard_doi' 
    directory, while others are saved in the 'fulltext_articles_doi' directory. 
    Additionally, it maintains sets of downloaded DOIs and article names to 
    prevent duplicate downloads and saves this information for future runs.
    """
    global downloaded_dois, downloaded_article_names

    # Define the header for the request
    headers_param = {
        'Accept': 'application/pdf',
        'X-ELS-APIKey': api_key,
        'X-ELS-Insttoken': inst_token
    }

    # Load downloaded info from the previous run
    load_downloaded_info()

    # Create directories to save the PDFs
    fulltext_articles_dir = 'downloaded_pdfs/fulltext_articles_doi'
    fulltext_editorialboard_dir = 'downloaded_pdfs/fulltext_editorialboard_doi'
    
    for pdf_dir in [fulltext_articles_dir, fulltext_editorialboard_dir]:
        if not os.path.exists(pdf_dir):
            os.makedirs(pdf_dir)
    
    for index, row in df.iterrows():
        doi = row[doi_column]
        article_title = row[title_column]

        # Check if the DOI has already been downloaded
        if doi in downloaded_dois:
            print(f"Article with DOI {doi} already downloaded. Skipping.")
            continue

        # Replace slashes (/) in the DOI with dots
        doi_filename = doi.replace('/', '.')

        # Determine the PDF directory based on the article title
        if article_title.lower() == 'editorial board':
            pdf_dir = fulltext_editorialboard_dir
        else:
            pdf_dir = fulltext_articles_dir

        # Define the PDF file path with DOI as the filename
        pdf_file_path = os.path.join(pdf_dir, f'{doi_filename}.pdf')
        
        # Send the GET request to retrieve the PDF content
        article_url = f'https://api.elsevier.com/content/article/doi/{doi}?view=FULL'
        response = requests.get(article_url, headers=headers_param)

        # Check if the request was successful (HTTP status code 200)
        if response.status_code == 200:
            
            # Save the PDF content to a file
            with open(pdf_file_path, 'wb') as pdf_file:
                pdf_file.write(response.content)
            
            # Add the DOI to the downloaded set
            downloaded_dois.add(doi)
            # Add the sanitized article name to the downloaded set
            downloaded_article_names.add(article_title)
        else:
            print(f"Failed to retrieve PDF for article with DOI {doi}. Status code: {response.status_code}")

    # Save downloaded info for the next run
    save_downloaded_info()

# %%
# Maintain a list of downloaded DOIs and article names
downloaded_dois = set()
downloaded_article_names = set()

download_pdf(api_key, inst_token, articles_df, doi_column='doi', title_column='title')
# Out:
# Article with DOI 10.1016/S1053-8119(22)00918-1 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119763 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119764 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119768 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119769 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119771 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119772 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119766 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119767 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119759 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119757 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119747 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119736 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119752 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119753 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119754 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119755 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119749 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119750 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119751 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119691 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119733 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119726 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119744 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119745 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119746 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119748 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119728 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119740 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119741 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119742 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119743 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119731 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119737 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119739 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119738 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119735 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119729 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119734 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119715 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119720 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119730 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119732 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119727 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119723 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119724 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119725 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119722 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00816-3 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119721 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119706 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119717 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119689 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119703 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119704 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119707 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119716 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119712 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119713 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119714 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119711 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119701 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119709 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119710 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119688 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119705 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119708 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119686 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119699 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119700 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119702 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119681 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119698 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119653 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119673 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119678 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119690 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119687 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119684 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119685 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119670 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119674 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119675 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119677 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119683 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119680 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119682 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119679 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119660 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119676 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119657 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119671 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119672 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119651 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119663 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119666 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119667 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119668 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119669 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119664 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119665 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119661 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119662 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119659 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119656 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119658 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119655 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119654 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119641 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119644 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119647 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119649 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119650 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119652 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119639 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119648 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119645 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119646 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119642 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119643 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119634 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119640 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119637 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119627 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119636 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119638 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119635 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119629 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119632 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119633 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119624 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119628 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119630 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119631 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119600 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119623 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119625 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119626 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119622 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119621 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00721-2 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119618 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119619 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119620 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119613 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119616 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119617 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119601 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119611 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119612 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119609 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119610 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119574 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119588 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119598 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119599 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119594 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119597 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119586 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119587 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119591 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119592 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119593 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119595 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119596 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119585 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119589 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119590 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119584 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119583 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119579 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119580 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119581 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119582 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00681-4 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119569 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119570 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119571 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119575 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119552 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119558 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119559 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119560 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119561 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119556 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119557 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119548 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119555 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00656-5 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119554 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119553 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119551 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119530 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119537 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119550 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119547 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119549 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119515 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119533 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119536 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119516 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119531 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119532 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119534 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119535 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119518 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119529 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119498 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119509 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119511 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119527 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119526 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119528 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119491 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119525 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119523 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119524 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119519 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119521 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119522 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119514 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119517 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119520 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119489 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119504 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119507 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119508 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119512 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119513 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119462 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119488 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119499 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119500 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119501 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119502 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119503 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119505 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119506 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119494 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119496 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119492 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119493 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119495 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119497 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119460 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119413 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119486 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119487 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119490 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00586-9 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119484 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119448 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119451 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119457 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119466 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119475 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119476 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119482 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119483 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119485 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119440 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119473 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119474 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119449 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119464 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119465 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119463 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119458 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119459 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119461 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119390 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119454 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119423 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00547-X already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119455 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119456 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119425 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119453 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119452 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119447 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119450 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119417 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119436 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119437 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119439 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119442 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119434 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119438 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119441 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119443 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119444 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119445 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119433 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119368 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119421 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119422 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119424 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119420 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119418 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119419 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119414 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119416 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119396 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119412 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119415 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119397 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119408 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119409 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119410 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119411 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119387 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119404 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119405 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119406 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119407 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119403 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119401 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119402 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119398 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119399 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119400 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119394 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119367 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00499-2 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119395 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119391 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119392 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119385 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119389 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119383 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119384 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119386 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119358 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119369 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119371 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119372 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119373 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119374 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119375 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119360 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119364 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119365 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119366 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119349 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119362 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119361 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119363 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119359 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119353 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119326 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119357 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119348 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119351 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119352 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119354 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119356 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119250 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119331 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119350 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119355 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119344 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119345 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119346 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119347 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119341 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119342 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119343 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119339 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119340 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119332 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119299 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119337 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119338 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119327 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119334 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119335 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119336 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119333 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119330 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00435-9 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119329 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119323 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119325 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119328 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119286 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119309 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119302 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119287 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119306 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119311 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119319 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119294 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119295 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119320 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119321 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119322 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00379-2 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119279 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119291 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119307 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119308 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119310 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119251 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119297 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119300 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119303 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119301 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119304 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119305 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119281 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119288 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119292 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119293 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119296 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119298 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119290 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119241 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119285 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119289 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119244 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119284 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119265 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119273 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00358-5 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119278 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119280 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119276 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119277 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119275 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119243 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119264 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119252 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119262 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119267 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119274 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119261 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119263 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119266 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119253 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119254 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119238 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119240 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119248 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119249 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119220 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119242 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119245 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119246 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119247 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119210 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119239 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00288-9 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119228 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119229 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119230 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119195 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119214 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119216 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119222 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119227 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119219 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119221 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119226 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119218 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119215 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119217 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119178 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119179 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119209 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119211 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119212 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119213 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119200 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119202 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119205 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119204 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119206 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119207 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119208 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119197 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119198 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119171 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119199 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119181 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119189 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119191 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119194 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119196 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119201 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119203 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119193 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119187 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119185 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119186 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119188 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119190 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119166 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119192 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119180 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119182 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119164 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119177 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119176 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119175 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119154 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119167 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119143 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119165 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119168 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119169 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119170 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119149 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119087 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119156 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119057 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119147 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119151 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119152 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119153 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119155 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119134 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119136 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119148 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119150 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119139 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119142 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119146 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00234-8 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119121 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119141 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119140 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119144 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119145 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118986 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119122 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119127 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119131 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119132 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119133 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119135 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119137 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119138 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119126 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119128 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119129 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119111 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119117 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119120 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119124 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119125 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119119 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119123 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119116 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119118 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119110 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00203-8 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119094 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119109 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119095 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119096 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119100 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119101 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119097 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119098 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119099 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119060 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119092 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119091 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119093 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119056 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119082 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119086 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119077 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119078 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119079 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119080 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119081 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119083 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119084 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119040 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119047 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119050 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119051 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119055 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119058 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119063 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119042 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119062 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119045 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119059 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119061 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119031 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119048 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119049 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119054 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119052 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119053 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119008 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119033 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119034 already downloaded. Skipping.
# ...
# Article with DOI 10.1016/j.neuroimage.2022.119010 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119011 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118992 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119002 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119003 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119004 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119005 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.119001 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118991 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118990 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00080-5 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118981 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118987 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118989 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118983 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118988 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118982 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118984 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118985 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118968 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118976 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118977 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118978 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118979 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118980 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118975 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118969 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118970 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118971 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118972 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118973 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118974 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118933 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118959 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118964 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118967 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118940 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118941 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118957 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118962 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118963 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118965 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118966 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118960 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118961 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118928 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118936 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118938 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118939 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118952 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118953 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118954 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118934 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118935 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118937 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118921 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118931 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118932 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00043-X already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118929 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118930 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118925 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118927 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118889 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118923 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118926 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118877 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118922 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118924 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(22)00014-3 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118920 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118918 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118919 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118903 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118909 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118902 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118906 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118907 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118908 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118865 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118904 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118874 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118888 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118895 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118900 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118901 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118890 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118891 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118892 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118893 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118894 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118872 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118878 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118879 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118887 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118871 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118873 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118875 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2022.118876 already downloaded. Skipping.
# Article with DOI 10.1016/S1053-8119(21)01130-7 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118869 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118870 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118863 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118866 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118867 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118868 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118854 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118862 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118830 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118837 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118849 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118864 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118822 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118839 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118845 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118840 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118848 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118852 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118853 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118847 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118850 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118851 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118825 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118841 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118842 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118843 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118846 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118790 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118812 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118835 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118836 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118838 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118844 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118795 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118833 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118834 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118813 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118828 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118831 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118832 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118728 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118823 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118826 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118827 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118829 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118824 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118791 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118818 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118819 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118820 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118821 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118788 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118811 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118784 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118786 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118794 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118796 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118809 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118810 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118801 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118802 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118778 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118797 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118798 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118799 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118800 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118792 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118793 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118775 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118787 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118789 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118779 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118780 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118781 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118782 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118783 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118746 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118760 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118765 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118777 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118773 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118776 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118742 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118748 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118763 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118761 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118768 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118770 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118774 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118739 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118767 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118744 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118751 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118756 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118727 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118745 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118714 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118738 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118698 already downloaded. Skipping.
# Article with DOI 10.1016/j.neuroimage.2021.118718 already downloaded. Skipping.

# %%
len(downloaded_dois)
# Out:
# 834

# %%
len(downloaded_article_names)
# Out:
# 816

# %%
len(articles_df['title'])
# Out:
# 834

# %% [markdown]
# <a name='references'></a>
# # 2. References
#
# - Elsapy. (2023). [Python]. Elsevier Developers. https://github.com/ElsevierDev/elsapy (Original work published 2016)
# - Elsevier B.V. (2023a). Article (Full Text) Retrieval API. Elsevier Developer Portal. https://dev.elsevier.com/documentation/ArticleRetrievalAPI.wadl#d1e52
# - Elsevier B.V. (2023b). Article Metadata API. Elsevier Developer Portal. https://dev.elsevier.com/documentation/ArticleMetadataAPI.wadl
# - Elsevier B.V. (2023c). ScienceDirect Article Metadata Guide. Elsevier Developer Portal. https://dev.elsevier.com/sd_article_meta_tips.html
# - Elsevier B.V. (2023d). ScienceDirect Search API Migration. Elsevier Developer Portal. https://dev.elsevier.com/tecdoc_sdsearch_migration.html

# %%
# ALTERNATIVE WHERE THE TITLE IS SAVED AS THE FILE NAME 

def sanitize_file_name(name):
    """
    This function takes an input string (file name) and removes special characters 
    while replacing spaces with underscores. It is used for creating clean and 
    valid file names.
    
    Parameters:
        name (str): The input string (file name) to be sanitized.

    Returns:
        sanitized_name (str): The sanitized version of the input string.
    """
    # Remove special characters and replace spaces with underscores
    sanitized_name = re.sub(r'[<>:"/\\|?*]', '', name)
    sanitized_name = sanitized_name.replace(' ', '_')
    return sanitized_name

def download_pdf_title(api_key, inst_token, df, doi_column='doi', title_column='title'):
    """
    This function downloads PDF articles based on their DOI and saves them in 
    specific directories. It checks if an article with the same DOI has been 
    downloaded before and avoids duplicate downloads.

    Parameters:
        api_key (str): The API key for accessing the Elsevier API.
        inst_token (str): The institution token for API access.
        df (pandas DataFrame): The DataFrame containing article information.
        doi_column (str, optional): The name of the DOI column in the DataFrame. Defaults to 'doi'.
        title_column (str, optional): The name of the article title column in the DataFrame. Defaults to 'title'.

    Note: This function also creates two directories ('fulltext_articles' and 
    'fulltext_editorialboard') to organize saved PDFs based on the article title. 
    PDFs with the title 'Editorial board' are saved in the 'fulltext_editorialboard' 
    directory, while others are saved in the 'fulltext_articles' directory. 
    Additionally, it maintains sets of downloaded DOIs and article names to 
    prevent duplicate downloads and saves this information for future runs.
    """
    
    global downloaded_dois, downloaded_article_names

    # Define the header for the request
    headers_param = {
        'Accept': 'application/pdf',
        'X-ELS-APIKey': api_key,
        'X-ELS-Insttoken': inst_token
    }

    # Load downloaded info from the previous run
    load_downloaded_info()

    # Create directories to save the PDFs
    fulltext_pdf_dir = 'downloaded_pdfs/fulltext_articles'
    editorialboard_pdf_dir = 'downloaded_pdfs/fulltext_editorialboard'
    
    for pdf_dir in [fulltext_pdf_dir, editorialboard_pdf_dir]:
        if not os.path.exists(pdf_dir):
            os.makedirs(pdf_dir)
    
    for index, row in df.iterrows():
        doi = row[doi_column]
        article_title = row[title_column]

        # Check if the DOI has already been downloaded
        if doi in downloaded_dois:
            print(f"Article with DOI {doi} already downloaded. Skipping.")
            continue

        # Sanitize the article title for use as a file name
        sanitized_title = sanitize_file_name(article_title)

        # Define the API endpoint for fetching the PDF
        article_url = f'https://api.elsevier.com/content/article/doi/{doi}?view=FULL'

        # Determine the PDF directory based on the article title
        if sanitized_title.lower() == 'editorial_board':
            pdf_dir = editorialboard_pdf_dir
        else:
            pdf_dir = fulltext_pdf_dir

        # Check if a file with the same title already exists
        pdf_file_path = os.path.join(pdf_dir, f'{sanitized_title}.pdf')
        counter = 1
        while os.path.exists(pdf_file_path):
            # If a file with the same title exists, add a suffix to the filename
            pdf_file_path = os.path.join(pdf_dir, f'{sanitized_title}_{counter}.pdf')
            counter += 1

        # Send the GET request to retrieve the PDF content
        response = requests.get(article_url, headers=headers_param)

        # Check if the request was successful (HTTP status code 200)
        if response.status_code == 200:
            
            # Save the PDF content to a file
            with open(pdf_file_path, 'wb') as pdf_file:
                pdf_file.write(response.content)
            
            # Add the DOI to the downloaded set
            downloaded_dois.add(doi)
            # Add the sanitized article name to the downloaded set
            downloaded_article_names.add(sanitized_title)
        else:
            print(f"Failed to retrieve PDF for article with DOI {doi}. Status code: {response.status_code}")

    # Save downloaded info for the next run
    save_downloaded_info()
